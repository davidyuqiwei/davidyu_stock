# %%
import jiagu
from davidyu_cfg import *
from functions.data_dir import *
from functions.get_datetime import *

data_dir = "/home/davidyu/stock/data/news_report/601398"


def get_knowledge(file_in):
    f = open(file_in,encoding=encode_in)
    content = f.read()
    kl = jiagu.knowledge(content)
    return kl

encode_in = "utf-8"
files = os.listdir(data_dir)
kl_in = []
for i in files:
    file_in = os.path.join(data_dir,i)
    out = get_knowledge(file_in)
    if len(out) > 0:
        kl_in.append(out)
# Out:
# 2020-09-27 17:24:59,953 - davidyu_cfg.py[line:39] - INFO: load log module
# 2020-09-27 17:24:59,973 - davidyu_cfg.py[line:41] - INFO: load data_dir module
# 2020-09-27 17:24:59,975 - davidyu_cfg.py[line:43] - INFO: load make_dir module

# %%
kl_in
# Out:
# [[['\n\t', '作者', '资产端']],
#  [['；上半年核销。。', '作者', '净息差'], ['；上半年核销。。', '作者', '净息差']],
#  [['2bp', '作者', '净']],
#  [['PE。', '作者', '净手续费'], ['PE。', '面积', '1215']],
#  [['PB', '作者', '净息差.'], ['PB', '上映时间', '2010年']],
#  [['。工商银行', '上映时间', '2016Q2']],
#  [['P/', '主演', 'M2']],
#  [['21bp。 ', '面积', '59'], ['21bp。 ', '人口数量', '69'], ['21bp。 ', '人口数量', '58']],
#  [['活期', '作者', '净息差'], ['活期', '上映时间', '不良']],
#  [[' ', '人口数量', '69']],
#  [['点', '作者', '净非息'], ['点', '作者', '净息差'], ['点', '作者', '净']],
#  [['H', '朝代', '三']],
#  [['活期环比且存款期限若加回', '作者', '净息差'],
#   ['活期环比且存款期限若加回', '作者', '净息差'],
#   ['活期环比且存款期限若加回', '作者', '资产端'],
#   ['活期环比且存款期限若加回', '上映时间', '不良']],
#  [['PE四大集团减少。', '作者', '四大行'],
#   ['PE四大集团减少。', '身高', '1'],
#   ['PE四大集团减少。', '主演', '倍']],
#  [['东亚。', '身高', '1'], ['东亚。', '出版社', '倍']],
#  [['活期占比空间。', '作者', '净息差'], ['活期占比空间。', '作者', '净息差']],
#  [['化解。。公司。', '身高', '1'], ['化解。。公司。', '身高', '1']],
#  [['估值', '身高', '2'], ['估值', '上映时间', '2007']],
#  [['H', '朝代', '三']],
#  [['；存款增速', '作者', '净'], ['；存款增速', '作者', '净'], ['；存款增速', '人口数量', '69']],
#  [['活期', '作者', '净息差'],
#   ['活期', '作者', '净息差方'],
#   ['活期', '作者', '净'],
#   ['活期', '作者', '净息差70']],
#  [['。客群客群 财务预测与元。', '出生地', ' ']],
#  [['信贷承诺 ', '出生地', ' '], ['倍。可比大行倍', '出生地', ' '], ['倍。可比大行倍', '注册资本', 'PB0.']],
#  [['代销保险。', '作者', '净息差'], ['代销保险。', '作者', '净增长']],
#  [[' 。', '作者', '净若']],
#  [['客户', '作者', '净息差'], ['客户', '占地面积', '69'], ['\xa0', '身高', '2']],
#  [['优异的客户。逾期贷款率', '作者', '净息差'],
#   ['优异的客户基础', '作者', '净'],
#   ['优异的客户基础', '作者', '净']],
#  [['。。', '出版社', '倍']],
#  [['化解。。公司。', '身高', '1'], ['化解。。公司。', '身高', '1']],
#  [['度监管使得存款增长的度的流失。\xa0', '作者', '净'], ['度监管使得存款增长的度的流失。\xa0', '作者', '净息差']],
#  [['季度来收益。%。', '作者', '信贷']],
#  [['银行股', '出品公司', '民生']],
#  [['慢于', '作者', '净逆周期']],
#  [['季度。', '作者', '净']],
#  [['季度银行增', '出版社', '倍'],
#   ['季度银行增', '作者', '净息差'],
#   ['季度银行增', '作者', '净息差'],
#   ['季度银行增', '注册资本', '3']],
#  [['端存款表现', '作者', '净']],
#  [['活期占比空间。', '作者', '净息差'], ['活期占比空间。', '作者', '净息差']],
#  [['。', '人口数量', '69倍']],
#  [['倍；对应。考虑到', '占地面积', '61825'],
#   ['倍；对应。考虑到', '人口数量', '64万亿'],
#   ['倍；对应。考虑到', '人口数量', '69']],
#  [[' 迹象。', '面积', '39']],
#  [['灵活性', '作者', '净拆']],
#  [['活期月末存款规模', '作者', '净息差..'], ['活期占比提升。', '作者', '净息差']],
#  [['PE集团。强。', '上映时间', '12'], ['PE集团。强。', '人口数量', '69']],
#  [['在工商银行倍。业绩', '作者', '净'], ['在工商银行倍。业绩', '作者', '净拆']],
#  [['保持工商银行', '主演', '活客'], ['客户质量的基础金融四。增量。。。银行中。', '作者', '实向虚']],
#  [['担保。三外源 ', '歌手', '单'],
#   ['担保。三外源 ', '作者', '资产端'],
#   ['担保。三外源 ', '身高', '2'],
#   ['担保。三外源 ', '作者', '净息差']],
#  [['H', '歌手', 'A '], ['H', '歌手', 'A/']],
#  [['活期', '上映时间', '2011'],
#   ['活期', '上映时间', '2011'],
#   ['活期', '上映时间', '2012年'],
#   ['活期', '人口数量', '69']],
#  [['科技铸就未来增长。有效减少无风险', '上映时间', '2006'],
#   ['科技铸就未来增长。有效减少无风险', '上映时间', '2006'],
#   ['科技铸就未来增长。有效减少无风险', '上映时间', '2006'],
#   ['科技铸就未来增长。有效减少无风险', '上映时间', '2006'],
#   ['科技铸就未来增长。有效减少无风险', '上映时间', '2006'],
#   ['科技铸就未来增长。有效减少无风险', '身高', '166']],
#  [['PE', '身高', '1']],
#  [['至', '作者', '净息差'], ['至', '上映时间', '2016'], ['至', '人口数量', '69']],
#  [['平台忧。媒', '人口数量', '69']],
#  [['工商银行余额', '作者', '净息差'], ['工商银行余额', '上映时间', '不良']],
#  [['\n\t', '作者', '资产端']],
#  [['日均', '作者', '净息差']],
#  [['存款优化影响。优先股', '作者', '负债端']],
#  [['长于银行', '作者', '净']],
#  [['倍和', '身高', '103']],
#  [['估值水平', '国籍', '中国']],
#  [['手续费。', '作者', '净'], ['手续费。', '作者', '净']],
#  [['倍。考虑到', '上映时间', '2011'], ['倍。考虑到', '人口数量', '69']],
#  [['高中汇率。风险资产', '作者', '净其他'],
#   ['高中汇率。风险资产', '作者', '净'],
#   ['高中汇率。风险资产', '主演', '汇兑'],
#   ['高中汇率。风险资产', '作者', '净']],
#  [['中央结算有限公司', '作者', '净股份行'], ['中央结算有限公司', '作者', '净未']],
#  [[' 。风险资产', '作者', '净'], [' 。风险资产', '作者', '净息差']],
#  [['中国', '面积', '4']],
#  [['中国工商银行汇率风险通过', '作者', '净息差'], ['中国工商银行汇率风险通过', '上映时间', '2008']],
#  [['活期月末存款规模', '作者', '净息差..'], ['活期占比提升。', '作者', '净息差']],
#  [['。存款活期化', '人口数量', '68']],
#  [['。。', '出版社', '倍']],
#  [['。温州不良。', '歌手', '明年']],
#  [['灵活性', '作者', '净拆']],
#  [['。', '成立日期', '2012年10月30'],
#   ['。', '出生日期', '1856'],
#   ['。', '身高', '13'],
#   ['工商银行', '作者', '净']],
#  [['态势。。。风险', '作者', '净'], ['态势。。。风险', '作者', '净息差'], ['态势。。。风险', '作者', '净息差']],
#  [['在工商银行倍。业绩', '作者', '净'], ['在工商银行倍。业绩', '作者', '净拆']],
#  [[' 的全年中国银行。我们', '作者', '净']],
#  [['PE', '面积', '39']],
#  [['期内。', '出品公司', '中']],
#  [['PE', '身高', '1']],
#  [['如果我们', '国籍', '中国']],
#  [['1bp。', '作者', '净']],
#  [['市', '身高', '1164'], ['市', '作者', '净息差'], ['市', '作者', '净息差']],
#  [[' 。', '身高', '182.']],
#  [['加息有限。的分行巴塞尔有限。\xa0', '作者', '净']],
#  [['季末', '上映时间', '201'], ['季末', '作者', '净手续费']],
#  [['。工商银行。增存款环比占比', '作者', '净'],
#   ['。工商银行。增存款环比占比', '作者', '净未'],
#   ['。工商银行。增存款环比占比', '作者', '净']],
#  [['。工商银行', '上映时间', '2009']],
#  [['中央结算有限公司', '作者', '净股份行'], ['中央结算有限公司', '作者', '净未']],
#  [['储备环比', '人口数量', '62x']],
#  [['活期环比且存款期限若加回', '作者', '净息差'],
#   ['活期环比且存款期限若加回', '作者', '净息差'],
#   ['活期环比且存款期限若加回', '作者', '资产端'],
#   ['活期环比且存款期限若加回', '上映时间', '不良']],
#  [['。', '上映时间', '2010'], ['。', '作者', '净手续费']],
#  [['银监会工商银行', '人口数量', '69']],
#  [['活期工商银行影响', '身高', '189'], ['活期工商银行影响', '作者', '净']],
#  [['长尾', '导演', '客']],
#  [['客户', '上映时间', '2017'], ['客户', '作者', '净息差'], ['客户', '占地面积', '69']],
#  [['。存款增量。', '出生日期', '1679'],
#   ['。存款增量。', '作者', '净息差'],
#   ['。存款增量。', '出生日期', '1679'],
#   ['。存款增量。', '作者', '净息差']],
#  [['季度工商银行的业绩', '身高', '155']],
#  [['2020。', '作者', '净息差'], ['2020。', '作者', '净']],
#  [['市盈率。资产质量恶化风险。\xa0', '作者', '净']],
#  [['重期限。公司', '作者', '净'], ['重期限。公司', '作者', '净息差']],
#  [['重', '上映时间', '1992'], ['重', '国籍', '中国'], ['重', '作者', '净']],
#  [['倍', '作者', '净']],
#  [['季度。', '作者', '净']],
#  [['重期限。公司', '作者', '净'], ['重期限。公司', '作者', '净息差']],
#  [['PB', '作者', '净息差'], ['PB', '作者', '净'], ['PB', '上映时间', '2010']],
#  [['活期', '作者', '净息差'],
#   ['活期', '作者', '净息差方'],
#   ['活期', '作者', '净'],
#   ['活期', '作者', '净息差70']],
#  [['重视存款争取', '作者', '净']],
#  [['活期', '作者', '净息差'], ['活期', '作者', '净息差']],
#  [['如果我们', '国籍', '中国']],
#  [[' ', '作者', '净']],
#  [['；可', '作者', '净净']],
#  [['合适进行。', '出品公司', '可']],
#  [['打开 我们预测倍', '身高', '2P']],
#  [['端存款表现', '作者', '净']],
#  [[' ', '作者', '资产端端']],
#  [['点', '作者', '净非息'], ['点', '作者', '净息差'], ['点', '作者', '净']],
#  [['2020。', '作者', '净息差'], ['2020。', '作者', '净']],
#  [['客户', '作者', '净息差'], ['客户', '占地面积', '69'], ['\xa0', '身高', '2']],
#  [['信贷承诺 ', '出生地', ' '], ['倍。可比大行倍', '出生地', ' '], ['倍。可比大行倍', '注册资本', 'PB0.']],
#  [['四大。', '作者', '净'], ['四大。', '作者', '资产端'], ['四大。', '作者', '净息差']],
#  [['活期', '作者', '净息差'], ['活期', '上映时间', '不良']],
#  [['担保。三外源 ', '歌手', '单'],
#   ['担保。三外源 ', '作者', '资产端'],
#   ['担保。三外源 ', '身高', '2'],
#   ['担保。三外源 ', '作者', '净息差']],
#  [['客户存款余额', '人口数量', '1745'],
#   ['客户存款余额', '作者', '净息差'],
#   ['客户存款余额', '上映时间', '2011'],
#   ['客户存款余额', '占地面积', '025']],
#  [['优异的客户。。疫情之。', '作者', '净息差'], ['优异的客户基础', '作者', '净']],
#  [['优异的客户基础', '作者', '净'], ['优异的客户基础', '作者', '净息差水平']],
#  [['；全年。科技', '作者', '净利息风险']],
#  [['工商银行', '成立日期', '2010年9月.元'], ['工商银行', '人口数量', '58元']],
#  [['季度。', '作者', '净']],
#  [['71bps。', '作者', '净74']],
#  [['季度', '作者', '净息差'], ['季度', '作者', '净']],
#  [['合适进行。', '出品公司', '可']],
#  [['信贷结构继续', '作者', '净']],
#  [['活期', '作者', '净']],
#  [['净利息存款结构和邮政。。', '作者', '负债']],
#  [['幅度', '作者', '净息差至']],
#  [['净。增长。', '作者', '净息差']],
#  [['独善其身工商银行', '上映时间', '2014'], ['独善其身工商银行', '国籍', '中国']],
#  [['高盛达成新', '出生地', '万亿'], ['高盛达成新', '作者', '净息差']],
#  [['PB', '人口数量', '42'], ['PB', '上映时间', '2010']],
#  [['AA支付规范。融e行', '作者', '净息差'], ['AA支付规范。融e行', '国籍', '中国']],
#  [[' 优化。工商银行', '作者', '净净']],
#  [['信贷结构继续', '作者', '净']],
#  [['标准银行经营。。。我们', '出生地', '南非']],
#  [['2020', '出生日期', '1bp']],
#  [['。存款增量。', '出生日期', '1679'],
#   ['。存款增量。', '作者', '净息差'],
#   ['。存款增量。', '出生日期', '1679'],
#   ['。存款增量。', '作者', '净息差']],
#  [['61bp。', '身高', '5'],
#   ['61bp。', '作者', '净'],
#   ['61bp。', '作者', '净'],
#   ['61bp。', '人口数量', '69'],
#   ['。增。增交易交运增。%永续', '上映时间', '2016']],
#  [[' ', '作者', '资产端端']],
#  [['长于银行', '作者', '净']],
#  [['  ', '注册资本', '936.89亿元']],
#  [['季度。', '作者', '净']],
#  [[' ', '作者', '净息差']],
#  [['AA支付规范。融e行', '作者', '净息差'], ['AA支付规范。融e行', '国籍', '中国']],
#  [[' ', '作者', '净息差']],
#  [['2pct。加剧', '作者', '净息差']],
#  [['PB', '人口数量', '69'], ['PB', '上映时间', '201282']],
#  [['担保承诺手续费', '人口数量', '69'], ['担保承诺手续费', '人口数量', '64']],
#  [['不良。', '作者', '净息差'],
#   ['不良。', '作者', '净'],
#   ['不良。', '作者', '净'],
#   ['活期。', '身高', '1']],
#  [['微调。观察。贷贷行。倍。\n', '人口数量', '6911-']],
#  [[' ', '作者', '净息差'], [' ', '作者', '四大行中']],
#  [['2bp不良', '作者', '净'], ['2bp不良', '出版社', '倍']],
#  [['长尾', '导演', '客']],
#  [['PB', '人口数量', '60'], ['PB', '作者', '净回拨']],
#  [['倍', '作者', '净'],
#   ['倍', '上映时间', '2019年'],
#   ['倍', '出生日期', '1pct'],
#   ['倍', '人口数量', '64']],
#  [[' ', '作者', '净'], [' ', '身高', '189']],
#  [['月末占比。。元。', '作者', '净息差'], ['月末占比。。元。', '作者', '利息']],
#  [['PE', '人口数量', '64']],
#  [['净', '作者', '净息差'], ['净', '人口数量', '42'], ['净', '导演', 'PE']],
#  [['空', '占地面积', '0.25元'], ['空', '占地面积', '69']],
#  [['慢于', '作者', '净逆周期']],
#  [['\xa0', '作者', '四大行']],
#  [['高。。', '作者', '三'],
#   ['高。。', '主演', '活客'],
#   ['高。。', '主演', '黏客'],
#   ['高。。', '主演', ' '],
#   ['高。。', '作者', '工银瑞信']],
#  [['倍', '作者', '净']],
#  [['。工商银行', '作者', '费用82'], ['。工商银行', '人口数量', '69']],
#  [['。资产端', '人口数量', '64'],
#   ['。资产端', '面积', '148'],
#   ['。资产端', '身高', '5'],
#   ['。资产端', '出生日期', '78/']],
#  [['中国工商银行。信贷风险管理高效率。', '上映时间', '2007']],
#  [['倍。\xa0我们的', '出版社', '倍']],
#  [['活期', '作者', '净息差'], ['活期', '作者', '净息差']],
#  [['H', '歌手', 'A '], ['H', '歌手', 'A/']],
#  [['细项分析\xa0银行', '身高', '156']],
#  [['中等', '身高', '1461']],
#  [['0公司', '面积', '39'],
#   ['0公司', '作者', '净损失'],
#   ['0公司', '作者', '净收益'],
#   ['0公司', '面积', '39']],
#  [['余额。和邮政', '作者', '净息差']],
#  [['科技铸就未来', '国籍', '中国']],
#  [['季度来收益。%。', '作者', '信贷']],
#  [[' ', '人口数量', '42']],
#  [['。工商银行', '作者', '费用82'], ['。工商银行', '人口数量', '69']],
#  [['至', '作者', '净息差'], ['至', '上映时间', '2016'], ['至', '人口数量', '69']],
#  [['71bps。', '作者', '净74']],
#  [['。工商银行', '上映时间', '2016Q2']],
#  [['高增驱动。强驱使', '作者', '净'],
#   ['高增驱动。强驱使', '作者', '净'],
#   ['高增驱动。强驱使', '作者', '净手续费'],
#   ['高增驱动。强驱使', '作者', '净']],
#  [['PB', '作者', '净'], ['PB', '作者', '净息差'], ['PB', '上映时间', '2010年']],
#  [['信贷结构持续优化下风险', '作者', '净'],
#   ['信贷结构持续优化下风险', '作者', '贷款端'],
#   ['净利息存款乃不良', '作者', '存款端'],
#   ['2020', '作者', '巴塞尔']],
#  [['。另外。的', '作者', '净息差'], ['。另外。的', '人口数量', '42'], ['。另外。的', '人口数量', '64']],
#  [['高中汇率。风险资产', '作者', '净其他'],
#   ['高中汇率。风险资产', '作者', '净'],
#   ['高中汇率。风险资产', '主演', '汇兑'],
#   ['高中汇率。风险资产', '作者', '净']],
#  [['四大。', '作者', '净'], ['四大。', '作者', '资产端'], ['四大。', '作者', '净息差']],
#  [['2pct。加剧', '作者', '净息差']],
#  [['\xa0', '作者', '四大行']],
#  [['倍。维持', '作者', '净'], ['倍。维持', '主演', ' ']],
#  [['高。。', '作者', '三'],
#   ['高。。', '主演', '活客'],
#   ['高。。', '主演', '黏客'],
#   ['高。。', '主演', ' '],
#   ['高。。', '作者', '工银瑞信']],
#  [['中国工商银行盛宴银行。银行', '国籍', '中国'], ['中国工商银行盛宴银行。银行', '成立日期', '1984年']],
#  [['信贷结构持续优化下风险', '作者', '净'],
#   ['信贷结构持续优化下风险', '作者', '贷款端'],
#   ['净利息存款乃不良', '作者', '存款端'],
#   ['2020', '作者', '巴塞尔']],
#  [['信贷结构。经济增长贷款风险。', '作者', '净息差'], ['信贷结构。经济增长贷款风险。', '朝代', '明年']],
#  [[' ', '主演', '于未来']],
#  [['倍。\n', '作者', '净息差']],
#  [['PE', '面积', '089亿张'], ['PE', '注册资本', '3700亿元'], ['PE', '身高', '166']],
#  [[' ', '人口数量', '42']],
#  [['末的剪刀差距略微有限。\xa0。剔除增值税影响空间。', '作者', '净息差'],
#   ['末的剪刀差距略微有限。\xa0。剔除增值税影响空间。', '作者', '净息差'],
#   ['末的剪刀差距略微有限。\xa0。剔除增值税影响空间。', '国籍', '中国']],
#  [['南非标准银行', '作者', '净.'], ['PB ', '出生地', ' ']],
#  [['2020', '出生日期', '1bp']],
#  [['PE', '身高', '1']],
#  [['全行', '作者', '净'], ['全行', '作者', '净'], ['全行', '作者', '净']],
#  [['保持工商银行', '主演', '活客'], ['客户质量的基础金融四。增量。。。银行中。', '作者', '实向虚']],
#  [['倍。 ', '身高', '1']],
#  [['市盈率。资产质量恶化风险。\xa0', '作者', '净']],
#  [['客户', '上映时间', '2017'], ['客户', '作者', '净息差'], ['客户', '占地面积', '69']],
#  [['PB ', '人口数量', '69']],
#  [['2bp', '作者', '净']],
#  [['净有限。我们预测费用像我们预测', '作者', '净']],
#  [['PB', '作者', '净'], ['PB', '上映时间', '2011年.']],
#  [['活期', '作者', '净']],
#  [['PE集团', '上映时间', '12'], ['PE集团', '人口数量', '69']],
#  [['末的剪刀差距略微有限。\xa0。剔除增值税影响空间。', '作者', '净息差'],
#   ['末的剪刀差距略微有限。\xa0。剔除增值税影响空间。', '作者', '净息差'],
#   ['末的剪刀差距略微有限。\xa0。剔除增值税影响空间。', '国籍', '中国']],
#  [[';', '作者', '净息差'], [';', '主演', '净']],
#  [['\xa0质量暂无碍。', '上映时间', '不良']],
#  [['余额 我们预测', '总部地点', '上海'], ['余额 我们预测', '成立日期', '2008年']],
#  [['。资产端', '人口数量', '64'],
#   ['。资产端', '面积', '148'],
#   ['。资产端', '身高', '5'],
#   ['。资产端', '出生日期', '78/']],
#  [['PE', '出生日期', '1582']],
#  [['PB', '作者', '净息差'], ['PB', '作者', '净73'], ['PB', '上映时间', '2012年']],
#  [['倍。维持', '作者', '净'], ['倍。维持', '主演', ' ']],
#  [['PB', '作者', '净'], ['PB', '上映时间', '2011']],
#  [['。温州不良。', '歌手', '明年']],
#  [['活期增长', '人口数量', '1745'],
#   ['活期增长', '作者', '净息差'],
#   ['活期增长', '身高', '168亿元'],
#   ['活期增长', '人口数量', '64'],
#   ['活期增长', '主演', '市']],
#  [['中国工商银行盛宴。\xa0银行。银行。', '成立日期', '1984年26']],
#  [['低于可比银行。', '出版社', '倍']],
#  [['。', '成立日期', '2012年10月30'],
#   ['。', '出生日期', '1856'],
#   ['。', '身高', '13'],
#   ['工商银行', '作者', '净']],
#  [['PE', '身高', '181789亿元'],
#   ['PE', '作者', '净息差'],
#   ['PE', '上映时间', '不良'],
#   ['PE', '人口数量', '64']],
#  [[' ', '作者', '净非']],
#  [['PE四大集团减少。', '作者', '四大行'],
#   ['PE四大集团减少。', '身高', '1'],
#   ['PE四大集团减少。', '主演', '倍']],
#  [['优异的客户基础', '作者', '净'], ['优异的客户基础', '作者', '净息差水平']],
#  [['有助于信贷增速', '作者', '净息差'], ['有助于信贷增速', '国籍', '中国'], ['有助于信贷增速', '作者', '净息差']],
#  [[' ', '人口数量', '69']],
#  [['全行', '作者', '净'], ['全行', '作者', '净'], ['全行', '作者', '净']],
#  [['月末占比。。元。', '作者', '净息差'], ['月末占比。。元。', '作者', '利息']],
#  [['结算', '身高', '130']],
#  [[' 的全年中国银行。我们', '作者', '净']],
#  [['。工商银行。增存款环比占比', '作者', '净'],
#   ['。工商银行。增存款环比占比', '作者', '净未'],
#   ['。工商银行。增存款环比占比', '作者', '净']],
#  [['61bp。', '身高', '5'],
#   ['61bp。', '作者', '净'],
#   ['61bp。', '作者', '净'],
#   ['61bp。', '人口数量', '69'],
#   ['。增。增交易交运增。%永续', '上映时间', '2016']],
#  [['。', '人口数量', '69倍']],
#  [['余额', '上映时间', '2011'], ['余额', '人口数量', '69']],
#  [['倍。', '上映时间', '2011']],
#  [['2020。供需弱化', '作者', '净']],
#  [['季度余额', '作者', '净'], ['季度余额', '作者', '净']],
#  [['\xa0。', '作者', '净']],
#  [[' 。风险资产', '作者', '净'], [' 。风险资产', '作者', '净息差']],
#  [['季度银行增', '出版社', '倍'],
#   ['季度银行增', '作者', '净息差'],
#   ['季度银行增', '作者', '净息差'],
#   ['季度银行增', '注册资本', '3']],
#  [[' 。', '作者', '净若']],
#  [['度监管使得存款增长的度的流失。\xa0', '作者', '净'], ['度监管使得存款增长的度的流失。\xa0', '作者', '净息差']],
#  [['重视存款争取', '作者', '净']],
#  [['季度余额', '作者', '净'], ['季度余额', '作者', '净']],
#  [['净的业绩空间。了', '作者', '净息差']],
#  [['倍。业绩', '人口数量', '58 '], ['倍。业绩', '主演', '市']],
#  [['独善其身工商银行', '上映时间', '2014'], ['独善其身工商银行', '国籍', '中国']],
#  [['无需融资。工行资产', '作者', '净']],
#  [['日均', '作者', '净息差']],
#  [['存款优化影响。优先股', '作者', '负债端']],
#  [['  ', '注册资本', '936.89亿元']],
#  [['代销保险。', '作者', '净息差'], ['代销保险。', '作者', '净增长']],
#  [['中国工商银行', '国籍', '中国'], ['中国工商银行', '成立日期', '1984年2736']],
#  [['2bp不良', '作者', '净'], ['2bp不良', '出版社', '倍']]]
